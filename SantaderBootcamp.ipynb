# %% [markdown]
# #Desafio de Projeto para Bootcamp santander

# %%
# importando Bibliotecas
import pandas as pd

# %% [markdown]
# ## 1° Extract

# %%
df = pd.read_csv('/Electric_Vehicle_Population_Data.csv')
df.head()
# Out:
#    VIN (1-10)  County       City State  Postal Code  Model Year       Make  \
# 0  5UXTA6C03P    King    Seattle    WA      98177.0      2023.0        BMW
# 1  1FMCU0EZXN  Yakima      Moxee    WA      98936.0      2022.0       FORD
# 2  1G1FW6S03J    King    Seattle    WA      98117.0      2018.0  CHEVROLET
# 3  5YJSA1AC0D    King  Newcastle    WA      98059.0      2013.0      TESLA
# 4  1FADP5CU8F  Kitsap  Bremerton    WA      98312.0      2015.0       FORD
#
#      Model                   Electric Vehicle Type  \
# 0       X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 1   ESCAPE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  BOLT EV          Battery Electric Vehicle (BEV)
# 3  MODEL S          Battery Electric Vehicle (BEV)
# 4    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            30.0
# 1           Clean Alternative Fuel Vehicle Eligible            38.0
# 2           Clean Alternative Fuel Vehicle Eligible           238.0
# 3           Clean Alternative Fuel Vehicle Eligible           208.0
# 4             Not eligible due to low battery range            19.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  36.0     218985539.0
# 1        0.0                  15.0     197264322.0
# 2        0.0                  36.0     168549727.0
# 3    69900.0                  41.0     244891062.0
# 4        0.0                  26.0     134915000.0
#
#                                  Vehicle Location  \
# 0   POINT (-122.38242499999996 47.77279000000004)
# 1   POINT (-120.37951169999997 46.55609000000004)
# 2  POINT (-122.37275999999997 47.689685000000054)
# 3  POINT (-122.15733999999998 47.487175000000036)
# 4                     POINT (-122.65223 47.57192)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 1                                     PACIFICORP       5.307700e+10
# 2   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 3  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 4                         PUGET SOUND ENERGY INC       5.303508e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96447 entries, 0 to 96446
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         96447 non-null  object
#  1   County                                             96445 non-null  object
#  2   City                                               96445 non-null  object
#  3   State                                              96446 non-null  object
#  4   Postal Code                                        96445 non-null  float64
#  5   Model Year                                         96446 non-null  float64
#  6   Make                                               96446 non-null  object
#  7   Model                                              96446 non-null  object
#  8   Electric Vehicle Type                              96446 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  96446 non-null  object
#  10  Electric Range                                     96446 non-null  float64
#  11  Base MSRP                                          96446 non-null  float64
#  12  Legislative District                               96414 non-null  float64
#  13  DOL Vehicle ID                                     96446 non-null  float64
#  14  Vehicle Location                                   96445 non-null  object
#  15  Electric Utility                                   96445 non-null  object
#  16  2020 Census Tract                                  96445 non-null  float64
# dtypes: float64(7), object(10)
# memory usage: 12.5+ MB

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                            0
# County                                                2
# City                                                  2
# State                                                 1
# Postal Code                                           2
# Model Year                                            1
# Make                                                  1
# Model                                                 1
# Electric Vehicle Type                                 1
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     1
# Electric Range                                        1
# Base MSRP                                             1
# Legislative District                                 33
# DOL Vehicle ID                                        1
# Vehicle Location                                      2
# Electric Utility                                      2
# 2020 Census Tract                                     2
# dtype: int64

# %%
df.describe()
# Out:
#         Postal Code    Model Year  Electric Range      Base MSRP  \
# count  96445.000000  96446.000000    96446.000000   96446.000000
# mean   98200.156338   2019.899322       71.360316    1358.110393
# std      870.896591      2.985496       97.523087    9523.776246
# min    12833.000000   1998.000000        0.000000       0.000000
# 25%    98040.000000   2018.000000        0.000000       0.000000
# 50%    98112.000000   2021.000000       20.000000       0.000000
# 75%    98277.000000   2022.000000      125.000000       0.000000
# max    99403.000000   2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count          96414.000000    9.644600e+04       9.644500e+04
# mean              31.301917    2.094164e+08       5.302607e+10
# std               14.420076    8.419004e+07       6.579063e+08
# min                1.000000    4.385000e+03       1.081042e+09
# 25%               21.000000    1.666907e+08       5.303301e+10
# 50%               36.000000    2.111301e+08       5.303302e+10
# 75%               44.000000    2.365741e+08       5.303303e+10
# max               49.000000    4.789346e+08       5.602100e+10

# %% [markdown]
# ##Transforme

# %%
df.columns = df.columns.str.replace(' ', '_').str.lower()

df.head()
# Out:
#    vin_(1-10)  county       city state  postal_code  model_year       make  \
# 0  5UXTA6C03P    King    Seattle    WA      98177.0      2023.0        BMW
# 1  1FMCU0EZXN  Yakima      Moxee    WA      98936.0      2022.0       FORD
# 2  1G1FW6S03J    King    Seattle    WA      98117.0      2018.0  CHEVROLET
# 3  5YJSA1AC0D    King  Newcastle    WA      98059.0      2013.0      TESLA
# 4  1FADP5CU8F  Kitsap  Bremerton    WA      98312.0      2015.0       FORD
#
#      model                   electric_vehicle_type  \
# 0       X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 1   ESCAPE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  BOLT EV          Battery Electric Vehicle (BEV)
# 3  MODEL S          Battery Electric Vehicle (BEV)
# 4    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   clean_alternative_fuel_vehicle_(cafv)_eligibility  electric_range  \
# 0           Clean Alternative Fuel Vehicle Eligible            30.0
# 1           Clean Alternative Fuel Vehicle Eligible            38.0
# 2           Clean Alternative Fuel Vehicle Eligible           238.0
# 3           Clean Alternative Fuel Vehicle Eligible           208.0
# 4             Not eligible due to low battery range            19.0
#
#    base_msrp  legislative_district  dol_vehicle_id  \
# 0        0.0                  36.0     218985539.0
# 1        0.0                  15.0     197264322.0
# 2        0.0                  36.0     168549727.0
# 3    69900.0                  41.0     244891062.0
# 4        0.0                  26.0     134915000.0
#
#                                  vehicle_location  \
# 0   POINT (-122.38242499999996 47.77279000000004)
# 1   POINT (-120.37951169999997 46.55609000000004)
# 2  POINT (-122.37275999999997 47.689685000000054)
# 3  POINT (-122.15733999999998 47.487175000000036)
# 4                     POINT (-122.65223 47.57192)
#
#                                 electric_utility  2020_census_tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 1                                     PACIFICORP       5.307700e+10
# 2   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 3  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 4                         PUGET SOUND ENERGY INC       5.303508e+10

# %% [markdown]
# ##LOAD

# %%
df.to_csv('Electric_Vehicle_Population_Data_without_id_column.csv', index=False)
print(df)
# Out:
#        vin_(1-10)     county        city state  postal_code  model_year  \
# 0      5UXTA6C03P       King     Seattle    WA      98177.0      2023.0
# 1      1FMCU0EZXN     Yakima       Moxee    WA      98936.0      2022.0
# 2      1G1FW6S03J       King     Seattle    WA      98117.0      2018.0
# 3      5YJSA1AC0D       King   Newcastle    WA      98059.0      2013.0
# 4      1FADP5CU8F     Kitsap   Bremerton    WA      98312.0      2015.0
# ...           ...        ...         ...   ...          ...         ...
# 96442  1G1RA6S51J     Pierce      Dupont    WA      98327.0      2018.0
# 96443  5YJ3E1EAXJ       King    Bellevue    WA      98004.0      2018.0
# 96444  5YJ3E1EA8M  Snohomish    Lynnwood    WA      98087.0      2021.0
# 96445  1N4BZ0CP7H     Pierce  Gig Harbor    WA      98335.0      2017.0
# 96446       YV4H6        NaN         NaN   NaN          NaN         NaN
#
#             make    model                   electric_vehicle_type  \
# 0            BMW       X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 1           FORD   ESCAPE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2      CHEVROLET  BOLT EV          Battery Electric Vehicle (BEV)
# 3          TESLA  MODEL S          Battery Electric Vehicle (BEV)
# 4           FORD    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# ...          ...      ...                                     ...
# 96442  CHEVROLET     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 96443      TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 96444      TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 96445     NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 96446        NaN      NaN                                     NaN
#
#        clean_alternative_fuel_vehicle_(cafv)_eligibility  electric_range  \
# 0                Clean Alternative Fuel Vehicle Eligible            30.0
# 1                Clean Alternative Fuel Vehicle Eligible            38.0
# 2                Clean Alternative Fuel Vehicle Eligible           238.0
# 3                Clean Alternative Fuel Vehicle Eligible           208.0
# 4                  Not eligible due to low battery range            19.0
# ...                                                  ...             ...
# 96442            Clean Alternative Fuel Vehicle Eligible            53.0
# 96443            Clean Alternative Fuel Vehicle Eligible           215.0
# 96444  Eligibility unknown as battery range has not b...             0.0
# 96445            Clean Alternative Fuel Vehicle Eligible           107.0
# 96446                                                NaN             NaN
#
#        base_msrp  legislative_district  dol_vehicle_id  \
# 0            0.0                  36.0     218985539.0
# 1            0.0                  15.0     197264322.0
# 2            0.0                  36.0     168549727.0
# 3        69900.0                  41.0     244891062.0
# 4            0.0                  26.0     134915000.0
# ...          ...                   ...             ...
# 96442        0.0                  28.0     303572139.0
# 96443        0.0                  41.0     336223247.0
# 96444        0.0                  21.0     180403583.0
# 96445        0.0                  26.0     340988672.0
# 96446        NaN                   NaN             NaN
#
#                                      vehicle_location  \
# 0       POINT (-122.38242499999996 47.77279000000004)
# 1       POINT (-120.37951169999997 46.55609000000004)
# 2      POINT (-122.37275999999997 47.689685000000054)
# 3      POINT (-122.15733999999998 47.487175000000036)
# 4                         POINT (-122.65223 47.57192)
# ...                                               ...
# 96442                   POINT (-122.643815 47.097455)
# 96443                    POINT (-122.201905 47.61385)
# 96444          POINT (-122.2559465 47.86567880000007)
# 96445                 POINT (-122.5835454 47.3234488)
# 96446                                             NaN
#
#                                         electric_utility  2020_census_tract
# 0           CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 1                                             PACIFICORP       5.307700e+10
# 2           CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 3          PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 4                                 PUGET SOUND ENERGY INC       5.303508e+10
# ...                                                  ...                ...
# 96442      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.305307e+10
# 96443      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 96444                             PUGET SOUND ENERGY INC       5.306104e+10
# 96445  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
# 96446                                                NaN                NaN
#
# [96447 rows x 17 columns]
